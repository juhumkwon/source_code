# %% [markdown]
# <a href="https://colab.research.google.com/github/juhumkwon/source_code/blob/main/Q_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# 환경 설정: 1차원 격자판 (예: 길이 5)
# 목표 지점은 상태 4
class Environment:
    def __init__(self):
        self.state_space = 5  # 상태 공간의 크기
        self.action_space = 2  # 행동 공간 (0: 왼쪽, 1: 오른쪽)

    def step(self, state, action):
        if action == 0:  # 왼쪽으로 이동
            next_state = max(0, state - 1)
        else:  # 오른쪽으로 이동
            next_state = min(self.state_space - 1, state + 1)

        # 보상 설정: 목표 지점 (상태 4)에 도달하면 +1 보상, 그 외에는 0 보상
        reward = 1 if next_state == 4 else 0
        done = next_state == 4
        return next_state, reward, done

# Q-learning 에이전트
class QAgent:
    def __init__(self, state_space, action_space, learning_rate=0.1, discount_factor=0.9, epsilon=1.0):
        self.q_table = np.zeros((state_space, action_space))
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.epsilon = epsilon
        self.epsilon_decay = 0.99
        self.epsilon_min = 0.1

    def choose_action(self, state):
        if np.random.rand() < self.epsilon:
            return np.random.choice(2)  # 무작위 선택
        return np.argmax(self.q_table[state])  # Q값이 가장 큰 행동 선택

    def learn(self, state, action, reward, next_state):
        best_future_q = np.max(self.q_table[next_state])
        target = reward + self.discount_factor * best_future_q
        self.q_table[state, action] += self.learning_rate * (target - self.q_table[state, action])
        # 탐색률 감소
        self.epsilon = max(self.epsilon * self.epsilon_decay, self.epsilon_min)

# 학습 수행
env = Environment()
agent = QAgent(state_space=5, action_space=2)

episodes = 100
for episode in range(episodes):
    state = 0  # 시작 상태
    total_reward = 0
    done = False

    while not done:
        action = agent.choose_action(state)
        next_state, reward, done = env.step(state, action)
        agent.learn(state, action, reward, next_state)
        state = next_state
        total_reward += reward

    print(f"Episode: {episode+1}, Total Reward: {total_reward}, Epsilon: {agent.epsilon:.2f}")

# 학습 후 Q-테이블 출력
print("\nQ-table after training:")
print(agent.q_table)
# Out:
# Episode: 1, Total Reward: 1, Epsilon: 0.61
# Episode: 2, Total Reward: 1, Epsilon: 0.22
# Episode: 3, Total Reward: 1, Epsilon: 0.14
# Episode: 4, Total Reward: 1, Epsilon: 0.10
# Episode: 5, Total Reward: 1, Epsilon: 0.10
# Episode: 6, Total Reward: 1, Epsilon: 0.10
# Episode: 7, Total Reward: 1, Epsilon: 0.10
# Episode: 8, Total Reward: 1, Epsilon: 0.10
# Episode: 9, Total Reward: 1, Epsilon: 0.10
# Episode: 10, Total Reward: 1, Epsilon: 0.10
# Episode: 11, Total Reward: 1, Epsilon: 0.10
# Episode: 12, Total Reward: 1, Epsilon: 0.10
# Episode: 13, Total Reward: 1, Epsilon: 0.10
# Episode: 14, Total Reward: 1, Epsilon: 0.10
# Episode: 15, Total Reward: 1, Epsilon: 0.10
# Episode: 16, Total Reward: 1, Epsilon: 0.10
# Episode: 17, Total Reward: 1, Epsilon: 0.10
# Episode: 18, Total Reward: 1, Epsilon: 0.10
# Episode: 19, Total Reward: 1, Epsilon: 0.10
# Episode: 20, Total Reward: 1, Epsilon: 0.10
# Episode: 21, Total Reward: 1, Epsilon: 0.10
# Episode: 22, Total Reward: 1, Epsilon: 0.10
# Episode: 23, Total Reward: 1, Epsilon: 0.10
# Episode: 24, Total Reward: 1, Epsilon: 0.10
# Episode: 25, Total Reward: 1, Epsilon: 0.10
# Episode: 26, Total Reward: 1, Epsilon: 0.10
# Episode: 27, Total Reward: 1, Epsilon: 0.10
# Episode: 28, Total Reward: 1, Epsilon: 0.10
# Episode: 29, Total Reward: 1, Epsilon: 0.10
# Episode: 30, Total Reward: 1, Epsilon: 0.10
# Episode: 31, Total Reward: 1, Epsilon: 0.10
# Episode: 32, Total Reward: 1, Epsilon: 0.10
# Episode: 33, Total Reward: 1, Epsilon: 0.10
# Episode: 34, Total Reward: 1, Epsilon: 0.10
# Episode: 35, Total Reward: 1, Epsilon: 0.10
# Episode: 36, Total Reward: 1, Epsilon: 0.10
# Episode: 37, Total Reward: 1, Epsilon: 0.10
# Episode: 38, Total Reward: 1, Epsilon: 0.10
# Episode: 39, Total Reward: 1, Epsilon: 0.10
# Episode: 40, Total Reward: 1, Epsilon: 0.10
# Episode: 41, Total Reward: 1, Epsilon: 0.10
# Episode: 42, Total Reward: 1, Epsilon: 0.10
# Episode: 43, Total Reward: 1, Epsilon: 0.10
# Episode: 44, Total Reward: 1, Epsilon: 0.10
# Episode: 45, Total Reward: 1, Epsilon: 0.10
# Episode: 46, Total Reward: 1, Epsilon: 0.10
# Episode: 47, Total Reward: 1, Epsilon: 0.10
# Episode: 48, Total Reward: 1, Epsilon: 0.10
# Episode: 49, Total Reward: 1, Epsilon: 0.10
# Episode: 50, Total Reward: 1, Epsilon: 0.10
# Episode: 51, Total Reward: 1, Epsilon: 0.10
# Episode: 52, Total Reward: 1, Epsilon: 0.10
# Episode: 53, Total Reward: 1, Epsilon: 0.10
# Episode: 54, Total Reward: 1, Epsilon: 0.10
# Episode: 55, Total Reward: 1, Epsilon: 0.10
# Episode: 56, Total Reward: 1, Epsilon: 0.10
# Episode: 57, Total Reward: 1, Epsilon: 0.10
# Episode: 58, Total Reward: 1, Epsilon: 0.10
# Episode: 59, Total Reward: 1, Epsilon: 0.10
# Episode: 60, Total Reward: 1, Epsilon: 0.10
# Episode: 61, Total Reward: 1, Epsilon: 0.10
# Episode: 62, Total Reward: 1, Epsilon: 0.10
# Episode: 63, Total Reward: 1, Epsilon: 0.10
# Episode: 64, Total Reward: 1, Epsilon: 0.10
# Episode: 65, Total Reward: 1, Epsilon: 0.10
# Episode: 66, Total Reward: 1, Epsilon: 0.10
# Episode: 67, Total Reward: 1, Epsilon: 0.10
# Episode: 68, Total Reward: 1, Epsilon: 0.10
# Episode: 69, Total Reward: 1, Epsilon: 0.10
# Episode: 70, Total Reward: 1, Epsilon: 0.10
# Episode: 71, Total Reward: 1, Epsilon: 0.10
# Episode: 72, Total Reward: 1, Epsilon: 0.10
# Episode: 73, Total Reward: 1, Epsilon: 0.10
# Episode: 74, Total Reward: 1, Epsilon: 0.10
# Episode: 75, Total Reward: 1, Epsilon: 0.10
# Episode: 76, Total Reward: 1, Epsilon: 0.10
# Episode: 77, Total Reward: 1, Epsilon: 0.10
# Episode: 78, Total Reward: 1, Epsilon: 0.10
# Episode: 79, Total Reward: 1, Epsilon: 0.10
# Episode: 80, Total Reward: 1, Epsilon: 0.10
# Episode: 81, Total Reward: 1, Epsilon: 0.10
# Episode: 82, Total Reward: 1, Epsilon: 0.10
# Episode: 83, Total Reward: 1, Epsilon: 0.10
# Episode: 84, Total Reward: 1, Epsilon: 0.10
# Episode: 85, Total Reward: 1, Epsilon: 0.10
# Episode: 86, Total Reward: 1, Epsilon: 0.10
# Episode: 87, Total Reward: 1, Epsilon: 0.10
# Episode: 88, Total Reward: 1, Epsilon: 0.10
# Episode: 89, Total Reward: 1, Epsilon: 0.10
# Episode: 90, Total Reward: 1, Epsilon: 0.10
# Episode: 91, Total Reward: 1, Epsilon: 0.10
# Episode: 92, Total Reward: 1, Epsilon: 0.10
# Episode: 93, Total Reward: 1, Epsilon: 0.10
# Episode: 94, Total Reward: 1, Epsilon: 0.10
# Episode: 95, Total Reward: 1, Epsilon: 0.10
# Episode: 96, Total Reward: 1, Epsilon: 0.10
# Episode: 97, Total Reward: 1, Epsilon: 0.10
# Episode: 98, Total Reward: 1, Epsilon: 0.10
# Episode: 99, Total Reward: 1, Epsilon: 0.10
# Episode: 100, Total Reward: 1, Epsilon: 0.10
#
# Q-table after training:
# [[0.19745522 0.72505437]
#  [0.16166848 0.80904716]
#  [0.33683917 0.89980313]
#  [0.40594751 0.99997344]
#  [0.         0.        ]]
