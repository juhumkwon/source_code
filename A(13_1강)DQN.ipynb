# %% [markdown]
# <a href="https://colab.research.google.com/github/juhumkwon/source_code/blob/main/A(13_1%EA%B0%95)DQN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import random
from collections import deque

# 환경 설정 (간단한 예시, 상태는 1차원, 행동은 4가지로 수정)
state_size = 4  # 상태 벡터 크기 (예: 4차원 상태)
action_size = 4  # 가능한 행동 수 (상, 하, 좌, 우 등 4가지 행동)

# DQN 파라미터
gamma = 0.95  # 할인율
learning_rate = 0.001  # 학습률
epsilon = 1.0  # 탐험 비율
epsilon_min = 0.01  # 탐험 비율의 최소값
epsilon_decay = 0.995  # 탐험 비율 감소값
batch_size = 32  # 학습할 때 사용할 배치 크기
memory_size = 2000  # 리플레이 메모리 크기
train_start = 1000  # 일정 경험을 쌓은 뒤부터 학습 시작
target_update_freq = 10  # 타겟 네트워크 업데이트 주기 (에피소드 단위)

# 리플레이 메모리
memory = deque(maxlen=memory_size)

# DQN 모델 정의
def build_model():
    model = tf.keras.Sequential()
    model.add(layers.Dense(24, input_dim=state_size, activation='relu'))  # 상태 벡터 크기에 맞는 입력 차원
    model.add(layers.Dense(24, activation='relu'))
    model.add(layers.Dense(action_size, activation='linear'))  # 행동 크기 (4)에 맞게 출력
    model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
    return model

# Q-네트워크 및 타겟 네트워크 생성
model = build_model()
target_model = build_model()

# 타겟 네트워크를 현재 Q 네트워크로 업데이트
def update_target_network():
    target_model.set_weights(model.get_weights())

# 경험 저장 (상태, 행동, 보상, 다음 상태, 종료 여부)
def store_experience(state, action, reward, next_state, done):
    memory.append((state, action, reward, next_state, done))

# 행동 선택 (epsilon-greedy)
def select_action(state):
    if np.random.rand() <= epsilon:
        return random.randrange(action_size)  # 랜덤 행동 (탐험)
    q_values = model.predict(state, verbose=0)  # Q-값 예측
    return np.argmax(q_values[0])  # Q-값이 가장 큰 행동 선택 (최적 행동)

# DQN 학습
def replay():
    global epsilon
    if len(memory) < train_start:
        return

    # 리플레이 메모리에서 무작위로 배치 샘플링
    minibatch = random.sample(memory, min(batch_size, len(memory)))

    # 학습할 데이터 준비
    for state, action, reward, next_state, done in minibatch:
        target = model.predict(state, verbose=0)

        if done:
            target[0][action] = reward  # 종료 상태인 경우, 보상만 반영
        else:
            # Q(s, a) = r + γ * max Q(s', a') (타겟 네트워크 사용)
            t = target_model.predict(next_state, verbose=0)
            target[0][action] = reward + gamma * np.amax(t[0])

        # 신경망 학습
        model.fit(state, target, epochs=1, verbose=0)

    # 탐험 비율 감소
    if epsilon > epsilon_min:
        epsilon *= epsilon_decay

# 환경 예시 (임의로 설정)
def get_initial_state():
    return np.reshape([0, 0, 0, 0], [1, state_size])  # (1, 4) 형태로 리쉐이프

def get_next_state(state, action):
    # 상태 전환 예시: 상태가 임의로 변한다고 가정 (실제 환경을 사용하면 다르게 구성)
    next_state = state + np.random.randn(1, state_size) * 0.1  # 임의로 작은 변화 추가
    reward = 1 if action == 1 else -1  # 예: 특정 행동에 대해 보상을 부여
    done = np.random.rand() < 0.1  # 10% 확률로 종료
    return next_state, reward, done

# DQN 학습 루프
episodes = 1000

for e in range(episodes):
    state = get_initial_state()  # 초기 상태 설정
    done = False
    while not done:
        action = select_action(state)  # 행동 선택
        next_state, reward, done = get_next_state(state, action)  # 다음 상태, 보상 획득
        store_experience(state, action, reward, next_state, done)  # 경험 저장
        state = next_state  # 상태 업데이트
        replay()  # 학습

    # 타겟 네트워크 업데이트
    if e % target_update_freq == 0:
        update_target_network()

    print(f"Episode: {e}/{episodes}, epsilon: {epsilon:.2f}")

print("DQN 학습 완료.")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Episode: 0/1000, epsilon: 1.00
# Episode: 1/1000, epsilon: 1.00
# Episode: 2/1000, epsilon: 1.00
# Episode: 3/1000, epsilon: 1.00
# Episode: 4/1000, epsilon: 1.00
# Episode: 5/1000, epsilon: 1.00
# Episode: 6/1000, epsilon: 1.00
# Episode: 7/1000, epsilon: 1.00
# Episode: 8/1000, epsilon: 1.00
# Episode: 9/1000, epsilon: 1.00
# Episode: 10/1000, epsilon: 1.00
# Episode: 11/1000, epsilon: 1.00
# Episode: 12/1000, epsilon: 1.00
# Episode: 13/1000, epsilon: 1.00
# Episode: 14/1000, epsilon: 1.00
# Episode: 15/1000, epsilon: 1.00
# Episode: 16/1000, epsilon: 1.00
# Episode: 17/1000, epsilon: 1.00
# Episode: 18/1000, epsilon: 1.00
# Episode: 19/1000, epsilon: 1.00
# Episode: 20/1000, epsilon: 1.00
# Episode: 21/1000, epsilon: 1.00
# Episode: 22/1000, epsilon: 1.00
# Episode: 23/1000, epsilon: 1.00
# Episode: 24/1000, epsilon: 1.00
# Episode: 25/1000, epsilon: 1.00
# Episode: 26/1000, epsilon: 1.00
# Episode: 27/1000, epsilon: 1.00
# Episode: 28/1000, epsilon: 1.00
# Episode: 29/1000, epsilon: 1.00
# Episode: 30/1000, epsilon: 1.00
# Episode: 31/1000, epsilon: 1.00
# Episode: 32/1000, epsilon: 1.00
# Episode: 33/1000, epsilon: 1.00
# Episode: 34/1000, epsilon: 1.00
# Episode: 35/1000, epsilon: 1.00
# Episode: 36/1000, epsilon: 1.00
# Episode: 37/1000, epsilon: 1.00
# Episode: 38/1000, epsilon: 1.00
# Episode: 39/1000, epsilon: 1.00
# Episode: 40/1000, epsilon: 1.00
# Episode: 41/1000, epsilon: 1.00
# Episode: 42/1000, epsilon: 1.00
# Episode: 43/1000, epsilon: 1.00
# Episode: 44/1000, epsilon: 1.00
# Episode: 45/1000, epsilon: 1.00
# Episode: 46/1000, epsilon: 1.00
# Episode: 47/1000, epsilon: 1.00
# Episode: 48/1000, epsilon: 1.00
# Episode: 49/1000, epsilon: 1.00
# Episode: 50/1000, epsilon: 1.00
# Episode: 51/1000, epsilon: 1.00
# Episode: 52/1000, epsilon: 1.00
# Episode: 53/1000, epsilon: 1.00
# Episode: 54/1000, epsilon: 1.00
# Episode: 55/1000, epsilon: 1.00
# Episode: 56/1000, epsilon: 1.00
# Episode: 57/1000, epsilon: 1.00
# Episode: 58/1000, epsilon: 1.00
# Episode: 59/1000, epsilon: 1.00
# Episode: 60/1000, epsilon: 1.00
# Episode: 61/1000, epsilon: 1.00
# Episode: 62/1000, epsilon: 1.00
# Episode: 63/1000, epsilon: 1.00
# Episode: 64/1000, epsilon: 1.00
# Episode: 65/1000, epsilon: 1.00
# Episode: 66/1000, epsilon: 1.00
# Episode: 67/1000, epsilon: 1.00
# Episode: 68/1000, epsilon: 1.00
# Episode: 69/1000, epsilon: 1.00
# Episode: 70/1000, epsilon: 1.00
# Episode: 71/1000, epsilon: 1.00
# Episode: 72/1000, epsilon: 1.00
# Episode: 73/1000, epsilon: 1.00
# Episode: 74/1000, epsilon: 1.00
# Episode: 75/1000, epsilon: 1.00
# Episode: 76/1000, epsilon: 1.00
# Episode: 77/1000, epsilon: 1.00
# Episode: 78/1000, epsilon: 1.00
# Episode: 79/1000, epsilon: 1.00
# Episode: 80/1000, epsilon: 1.00
# Episode: 81/1000, epsilon: 1.00
# Episode: 82/1000, epsilon: 1.00
# Episode: 83/1000, epsilon: 1.00
# Episode: 84/1000, epsilon: 1.00
# Episode: 85/1000, epsilon: 1.00
# Episode: 86/1000, epsilon: 1.00
# Episode: 87/1000, epsilon: 1.00
# Episode: 88/1000, epsilon: 1.00
# Episode: 89/1000, epsilon: 1.00
# Episode: 90/1000, epsilon: 1.00
# Episode: 91/1000, epsilon: 1.00
# Episode: 92/1000, epsilon: 1.00
# Episode: 93/1000, epsilon: 1.00
# Episode: 94/1000, epsilon: 1.00
# Episode: 95/1000, epsilon: 1.00
# Episode: 96/1000, epsilon: 1.00
# Episode: 97/1000, epsilon: 1.00
# Episode: 98/1000, epsilon: 1.00
# Episode: 99/1000, epsilon: 1.00
# Episode: 100/1000, epsilon: 1.00
# Episode: 101/1000, epsilon: 1.00
# Episode: 102/1000, epsilon: 1.00
# Episode: 103/1000, epsilon: 1.00
# Episode: 104/1000, epsilon: 1.00
# Episode: 105/1000, epsilon: 1.00
# Episode: 106/1000, epsilon: 1.00
# Episode: 107/1000, epsilon: 1.00
# Episode: 108/1000, epsilon: 1.00
# Episode: 109/1000, epsilon: 1.00
# Episode: 110/1000, epsilon: 1.00
# Episode: 111/1000, epsilon: 1.00
# Episode: 112/1000, epsilon: 1.00
# Episode: 113/1000, epsilon: 1.00
# Episode: 114/1000, epsilon: 1.00
# Episode: 115/1000, epsilon: 1.00
# Episode: 116/1000, epsilon: 1.00
# Episode: 117/1000, epsilon: 1.00
# Episode: 118/1000, epsilon: 1.00
# Episode: 119/1000, epsilon: 1.00
# Episode: 120/1000, epsilon: 0.97
# Episode: 121/1000, epsilon: 0.96
# Episode: 122/1000, epsilon: 0.86
# Episode: 123/1000, epsilon: 0.79
# Episode: 124/1000, epsilon: 0.74
# Episode: 125/1000, epsilon: 0.71
# Episode: 126/1000, epsilon: 0.69
# Episode: 127/1000, epsilon: 0.66
# Episode: 128/1000, epsilon: 0.58
# Episode: 129/1000, epsilon: 0.57
# Episode: 130/1000, epsilon: 0.57
# Episode: 131/1000, epsilon: 0.53
