# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
from sklearn import metrics
from google.colab import drive
from google.colab import files

#file_uploaded = files.upload()
#drive.mount('/content/drive')
drive.mount('/content/sample_data/california_housing_testcsv')
# Out:
# Drive already mounted at /content/sample_data/california_housing_testcsv; to attempt to forcibly remount, call drive.mount("/content/sample_data/california_housing_testcsv", force_remount=True).
