# %% [markdown]
# <a href="https://colab.research.google.com/github/juhumkwon/source_code/blob/main/4_2_1_Iris_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%82%B0%EC%A0%90%EB%8F%84_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터프레임으로 변환
import pandas as pd
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

"""
sns.pairplot은 seaborn 라이브러리에서 제공하는 함수로, 데이터의 피처들 간의 쌍(pair)별 산점도를 시각화하는 데 사용됩니다.
이 함수는 데이터셋의 피처들 간의 관계를 한눈에 파악할 수 있게 해줍니다.
특히, hue 파라미터를 사용하면 클래스 레이블에 따라 다른 색으로 데이터를 표시할 수 있습니다.
이를 통해 클래스 간의 구분을 시각적으로 이해하는 데 유용합니다.
"""
# 산점도 시각화
sns.pairplot(df, hue='species')
plt.show()

# %%
import seaborn as sns
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt

# 데이터 로드
iris = datasets.load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names

# 데이터프레임 생성
df = pd.DataFrame(X, columns=feature_names)
df['species'] = target_names[y]

# Pairplot 그리기
sns.pairplot(df, hue='species')
plt.show()

# %%
import seaborn as sns
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt

# 데이터 로드
iris = datasets.load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names

# 데이터프레임 생성
df = pd.DataFrame(X, columns=feature_names)
df['species'] = target_names[y]

# Pairplot 그리기
sns.pairplot(df, hue='species', palette='viridis')
plt.show()
