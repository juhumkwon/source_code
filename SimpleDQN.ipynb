# %% [markdown]
# <a href="https://colab.research.google.com/github/juhumkwon/source_code/blob/main/SimpleDQN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import random

# Simple 1D 환경 정의
class Simple1DWorld:
    def __init__(self):
        self.state_size = 5
        self.reset()

    def reset(self):
        self.pos = 2  # 시작 위치는 가운데 (2)
        return self._get_state()

    def _get_state(self):
        state = np.zeros(self.state_size)
        state[self.pos] = 1
        return state.reshape(1, -1)  # 2D 형태로 반환

    def step(self, action):
        if action == 0 and self.pos > 0:
            self.pos -= 1   # 왼쪽 이동
        elif action == 1 and self.pos < self.state_size - 1:
            self.pos += 1   # 오른쪽 이동

        done = self.pos == self.state_size - 1
        reward = 10 if done else 0
        return self._get_state(), reward, done

# Q-Network 모델 정의
def build_model(input_dim, output_dim):
    model = models.Sequential([
        layers.Dense(32, activation='relu', input_shape=(input_dim,)),
        layers.Dense(32, activation='relu'),
        layers.Dense(output_dim)
    ])
    model.compile(optimizer='adam', loss='mse')
    return model

# DQN 학습 함수
def train_dqn():
    env = Simple1DWorld()
    state_size = env.state_size
    action_size = 2
    q_model = build_model(state_size, action_size)
    target_model = build_model(state_size, action_size)
    target_model.set_weights(q_model.get_weights())

    memory = []
    gamma = 0.95
    epsilon = 1.0
    epsilon_min = 0.01
    epsilon_decay = 0.99
    batch_size = 32
    episodes = 50  # 줄여서 테스트 가능

    for ep in range(episodes):
        state = env.reset()
        total_reward = 0
        done = False

        while not done:
            # 행동 선택 (ε-greedy)
            if np.random.rand() < epsilon:
                action = np.random.choice(action_size)
            else:
                q_values = q_model.predict(state, verbose=0)
                action = np.argmax(q_values[0])

            # 에이전트 위치와 행동 출력
            print(f"[EP {ep+1}] pos: {env.pos}, action: {action}")

            # 환경 반응
            next_state, reward, done = env.step(action)
            memory.append((state, action, reward, next_state, done))
            state = next_state
            total_reward += reward

            # 학습
            if len(memory) >= batch_size:
                minibatch = random.sample(memory, batch_size)
                states = np.vstack([m[0] for m in minibatch])
                actions = [m[1] for m in minibatch]
                rewards = [m[2] for m in minibatch]
                next_states = np.vstack([m[3] for m in minibatch])
                dones = [m[4] for m in minibatch]

                targets = q_model.predict(states, verbose=0)
                next_qs = target_model.predict(next_states, verbose=0)

                for i in range(batch_size):
                    if dones[i]:
                        targets[i][actions[i]] = rewards[i]
                    else:
                        targets[i][actions[i]] = rewards[i] + gamma * np.max(next_qs[i])

                q_model.fit(states, targets, epochs=1, verbose=0)

        # 타겟 네트워크 업데이트
        if ep % 10 == 0:
            target_model.set_weights(q_model.get_weights())

        # ε 감소
        if epsilon > epsilon_min:
            epsilon *= epsilon_decay

        print(f"Episode {ep+1}: Total reward = {total_reward}, Epsilon = {epsilon:.3f}")

# 실행
if __name__ == '__main__':
    train_dqn()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#
# Episode 12: Total reward = 10, Epsilon = 0.886
# [EP 13] pos: 2, action: 0
# [EP 13] pos: 1, action: 1
# [EP 13] pos: 2, action: 0
# [EP 13] pos: 1, action: 1
# [EP 13] pos: 2, action: 0
# [EP 13] pos: 1, action: 0
# [EP 13] pos: 0, action: 1
# [EP 13] pos: 1, action: 1
# [EP 13] pos: 2, action: 1
# [EP 13] pos: 3, action: 0
# [EP 13] pos: 2, action: 1
# [EP 13] pos: 3, action: 1
# Episode 13: Total reward = 10, Epsilon = 0.878
# [EP 14] pos: 2, action: 1
# [EP 14] pos: 3, action: 0
# [EP 14] pos: 2, action: 0
# [EP 14] pos: 1, action: 1
# [EP 14] pos: 2, action: 1
# [EP 14] pos: 3, action: 0
# [EP 14] pos: 2, action: 1
# [EP 14] pos: 3, action: 0
# [EP 14] pos: 2, action: 1
# [EP 14] pos: 3, action: 1
# Episode 14: Total reward = 10, Epsilon = 0.869
# [EP 15] pos: 2, action: 0
# [EP 15] pos: 1, action: 1
# [EP 15] pos: 2, action: 1
# [EP 15] pos: 3, action: 0
# [EP 15] pos: 2, action: 1
# [EP 15] pos: 3, action: 0
# [EP 15] pos: 2, action: 1
# [EP 15] pos: 3, action: 1
# Episode 15: Total reward = 10, Epsilon = 0.860
# [EP 16] pos: 2, action: 1
# [EP 16] pos: 3, action: 0
# [EP 16] pos: 2, action: 1
# [EP 16] pos: 3, action: 0
# [EP 16] pos: 2, action: 1
# [EP 16] pos: 3, action: 1
# Episode 16: Total reward = 10, Epsilon = 0.851
# [EP 17] pos: 2, action: 1
# [EP 17] pos: 3, action: 0
# [EP 17] pos: 2, action: 0
# [EP 17] pos: 1, action: 1
# [EP 17] pos: 2, action: 0
# [EP 17] pos: 1, action: 0
# [EP 17] pos: 0, action: 1
# [EP 17] pos: 1, action: 1
# [EP 17] pos: 2, action: 0
# [EP 17] pos: 1, action: 0
# [EP 17] pos: 0, action: 0
# [EP 17] pos: 0, action: 1
# [EP 17] pos: 1, action: 1
# [EP 17] pos: 2, action: 1
# [EP 17] pos: 3, action: 0
# [EP 17] pos: 2, action: 0
# [EP 17] pos: 1, action: 1
# [EP 17] pos: 2, action: 0
# [EP 17] pos: 1, action: 1
# [EP 17] pos: 2, action: 0
# [EP 17] pos: 1, action: 0
# [EP 17] pos: 0, action: 0
# [EP 17] pos: 0, action: 1
# [EP 17] pos: 1, action: 1
# [EP 17] pos: 2, action: 0
# [EP 17] pos: 1, action: 1
# [EP 17] pos: 2, action: 0
# [EP 17] pos: 1, action: 0
# [EP 17] pos: 0, action: 1
# [EP 17] pos: 1, action: 1
# [EP 17] pos: 2, action: 1
# [EP 17] pos: 3, action: 0
# [EP 17] pos: 2, action: 1
# [EP 17] pos: 3, action: 1
# Episode 17: Total reward = 10, Epsilon = 0.843
# [EP 18] pos: 2, action: 1
# [EP 18] pos: 3, action: 0
# [EP 18] pos: 2, action: 1
# [EP 18] pos: 3, action: 0
# [EP 18] pos: 2, action: 0
# [EP 18] pos: 1, action: 1
# [EP 18] pos: 2, action: 1
# [EP 18] pos: 3, action: 0
# [EP 18] pos: 2, action: 1
# [EP 18] pos: 3, action: 0
# [EP 18] pos: 2, action: 1
# [EP 18] pos: 3, action: 0
# [EP 18] pos: 2, action: 0
# [EP 18] pos: 1, action: 1
# [EP 18] pos: 2, action: 1
# [EP 18] pos: 3, action: 1
# Episode 18: Total reward = 10, Epsilon = 0.835
# [EP 19] pos: 2, action: 1
# [EP 19] pos: 3, action: 0
# [EP 19] pos: 2, action: 1
# [EP 19] pos: 3, action: 1
# Episode 19: Total reward = 10, Epsilon = 0.826
# [EP 20] pos: 2, action: 1
# [EP 20] pos: 3, action: 1
# Episode 20: Total reward = 10, Epsilon = 0.818
# [EP 21] pos: 2, action: 0
# [EP 21] pos: 1, action: 1
# [EP 21] pos: 2, action: 1
# [EP 21] pos: 3, action: 1
# Episode 21: Total reward = 10, Epsilon = 0.810
# [EP 22] pos: 2, action: 1
# [EP 22] pos: 3, action: 1
# Episode 22: Total reward = 10, Epsilon = 0.802
# [EP 23] pos: 2, action: 0
# [EP 23] pos: 1, action: 1
# [EP 23] pos: 2, action: 1
# [EP 23] pos: 3, action: 1
# Episode 23: Total reward = 10, Epsilon = 0.794
# [EP 24] pos: 2, action: 0
# [EP 24] pos: 1, action: 1
# [EP 24] pos: 2, action: 1
# [EP 24] pos: 3, action: 1
# Episode 24: Total reward = 10, Epsilon = 0.786
# [EP 25] pos: 2, action: 1
# [EP 25] pos: 3, action: 1
# Episode 25: Total reward = 10, Epsilon = 0.778
# [EP 26] pos: 2, action: 1
# [EP 26] pos: 3, action: 0
# [EP 26] pos: 2, action: 1
# [EP 26] pos: 3, action: 0
# [EP 26] pos: 2, action: 1
# [EP 26] pos: 3, action: 0
# [EP 26] pos: 2, action: 1
# [EP 26] pos: 3, action: 1
# Episode 26: Total reward = 10, Epsilon = 0.770
# [EP 27] pos: 2, action: 1
# [EP 27] pos: 3, action: 0
# [EP 27] pos: 2, action: 0
# [EP 27] pos: 1, action: 0
# [EP 27] pos: 0, action: 1
# [EP 27] pos: 1, action: 1
# [EP 27] pos: 2, action: 1
# [EP 27] pos: 3, action: 0
# [EP 27] pos: 2, action: 1
# [EP 27] pos: 3, action: 1
# Episode 27: Total reward = 10, Epsilon = 0.762
# [EP 28] pos: 2, action: 1
# [EP 28] pos: 3, action: 0
# [EP 28] pos: 2, action: 1
# [EP 28] pos: 3, action: 0
# [EP 28] pos: 2, action: 1
# [EP 28] pos: 3, action: 1
# Episode 28: Total reward = 10, Epsilon = 0.755
# [EP 29] pos: 2, action: 0
# [EP 29] pos: 1, action: 1
# [EP 29] pos: 2, action: 1
# [EP 29] pos: 3, action: 1
# Episode 29: Total reward = 10, Epsilon = 0.747
# [EP 30] pos: 2, action: 0
# [EP 30] pos: 1, action: 1
# [EP 30] pos: 2, action: 1
# [EP 30] pos: 3, action: 1
# Episode 30: Total reward = 10, Epsilon = 0.740
# [EP 31] pos: 2, action: 0
# [EP 31] pos: 1, action: 1
# [EP 31] pos: 2, action: 1
# [EP 31] pos: 3, action: 1
# Episode 31: Total reward = 10, Epsilon = 0.732
# [EP 32] pos: 2, action: 0
# [EP 32] pos: 1, action: 1
# [EP 32] pos: 2, action: 1
# [EP 32] pos: 3, action: 0
# [EP 32] pos: 2, action: 0
# [EP 32] pos: 1, action: 1
# [EP 32] pos: 2, action: 1
# [EP 32] pos: 3, action: 1
# Episode 32: Total reward = 10, Epsilon = 0.725
# [EP 33] pos: 2, action: 1
# [EP 33] pos: 3, action: 1
# Episode 33: Total reward = 10, Epsilon = 0.718
# [EP 34] pos: 2, action: 1
# [EP 34] pos: 3, action: 0
# [EP 34] pos: 2, action: 1
# [EP 34] pos: 3, action: 1
# Episode 34: Total reward = 10, Epsilon = 0.711
# [EP 35] pos: 2, action: 0
# [EP 35] pos: 1, action: 1
# [EP 35] pos: 2, action: 1
# [EP 35] pos: 3, action: 0
# [EP 35] pos: 2, action: 0
# [EP 35] pos: 1, action: 0
# [EP 35] pos: 0, action: 1
# [EP 35] pos: 1, action: 1
# [EP 35] pos: 2, action: 1
# [EP 35] pos: 3, action: 1
# Episode 35: Total reward = 10, Epsilon = 0.703
# [EP 36] pos: 2, action: 1
# [EP 36] pos: 3, action: 0
# [EP 36] pos: 2, action: 0
# [EP 36] pos: 1, action: 1
# [EP 36] pos: 2, action: 1
# [EP 36] pos: 3, action: 0
# [EP 36] pos: 2, action: 1
# [EP 36] pos: 3, action: 1
# Episode 36: Total reward = 10, Epsilon = 0.696
# [EP 37] pos: 2, action: 0
# [EP 37] pos: 1, action: 1
# [EP 37] pos: 2, action: 1
# [EP 37] pos: 3, action: 1
# Episode 37: Total reward = 10, Epsilon = 0.689
# [EP 38] pos: 2, action: 1
# [EP 38] pos: 3, action: 1
# Episode 38: Total reward = 10, Epsilon = 0.683
# [EP 39] pos: 2, action: 0
# [EP 39] pos: 1, action: 1
# [EP 39] pos: 2, action: 0
# [EP 39] pos: 1, action: 1
# [EP 39] pos: 2, action: 1
# [EP 39] pos: 3, action: 0
# [EP 39] pos: 2, action: 0
# [EP 39] pos: 1, action: 0
# [EP 39] pos: 0, action: 1
# [EP 39] pos: 1, action: 1
# [EP 39] pos: 2, action: 0
# [EP 39] pos: 1, action: 0
# [EP 39] pos: 0, action: 1
# [EP 39] pos: 1, action: 1
# [EP 39] pos: 2, action: 0
# [EP 39] pos: 1, action: 1
# [EP 39] pos: 2, action: 1
# [EP 39] pos: 3, action: 1
# Episode 39: Total reward = 10, Epsilon = 0.676
# [EP 40] pos: 2, action: 1
# [EP 40] pos: 3, action: 1
# Episode 40: Total reward = 10, Epsilon = 0.669
# [EP 41] pos: 2, action: 0
# [EP 41] pos: 1, action: 1
# [EP 41] pos: 2, action: 1
# [EP 41] pos: 3, action: 0
# [EP 41] pos: 2, action: 0
# [EP 41] pos: 1, action: 1
# [EP 41] pos: 2, action: 1
# [EP 41] pos: 3, action: 0
# [EP 41] pos: 2, action: 1
# [EP 41] pos: 3, action: 1
# Episode 41: Total reward = 10, Epsilon = 0.662
# [EP 42] pos: 2, action: 1
# [EP 42] pos: 3, action: 1
# Episode 42: Total reward = 10, Epsilon = 0.656
# [EP 43] pos: 2, action: 0
# [EP 43] pos: 1, action: 1
# [EP 43] pos: 2, action: 1
# [EP 43] pos: 3, action: 1
# Episode 43: Total reward = 10, Epsilon = 0.649
# [EP 44] pos: 2, action: 0
# [EP 44] pos: 1, action: 1
# [EP 44] pos: 2, action: 0
# [EP 44] pos: 1, action: 0
# [EP 44] pos: 0, action: 1
# [EP 44] pos: 1, action: 0
# [EP 44] pos: 0, action: 1
# [EP 44] pos: 1, action: 1
# [EP 44] pos: 2, action: 0
# [EP 44] pos: 1, action: 1
# [EP 44] pos: 2, action: 0
# [EP 44] pos: 1, action: 1
# [EP 44] pos: 2, action: 0
# [EP 44] pos: 1, action: 1
# [EP 44] pos: 2, action: 1
# [EP 44] pos: 3, action: 0
# [EP 44] pos: 2, action: 1
# [EP 44] pos: 3, action: 1
# Episode 44: Total reward = 10, Epsilon = 0.643
# [EP 45] pos: 2, action: 1
# [EP 45] pos: 3, action: 1
# Episode 45: Total reward = 10, Epsilon = 0.636
# [EP 46] pos: 2, action: 1
# [EP 46] pos: 3, action: 0
# [EP 46] pos: 2, action: 1
# [EP 46] pos: 3, action: 1
# Episode 46: Total reward = 10, Epsilon = 0.630
# [EP 47] pos: 2, action: 1
# [EP 47] pos: 3, action: 1
# Episode 47: Total reward = 10, Epsilon = 0.624
# [EP 48] pos: 2, action: 0
# [EP 48] pos: 1, action: 1
# [EP 48] pos: 2, action: 1
# [EP 48] pos: 3, action: 1
# Episode 48: Total reward = 10, Epsilon = 0.617
# [EP 49] pos: 2, action: 0
# [EP 49] pos: 1, action: 0
# [EP 49] pos: 0, action: 1
# [EP 49] pos: 1, action: 0
# [EP 49] pos: 0, action: 1
# [EP 49] pos: 1, action: 0
# [EP 49] pos: 0, action: 1
# [EP 49] pos: 1, action: 1
# [EP 49] pos: 2, action: 1
# [EP 49] pos: 3, action: 0
# [EP 49] pos: 2, action: 1
# [EP 49] pos: 3, action: 1
# Episode 49: Total reward = 10, Epsilon = 0.611
# [EP 50] pos: 2, action: 1
# [EP 50] pos: 3, action: 1
# Episode 50: Total reward = 10, Epsilon = 0.605
